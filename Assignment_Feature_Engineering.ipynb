# %% [markdown]
# Q1.What is a parameter?
# - A parameter is a value inside a model that the model learns during training, like weights.
#
# Q2.What is correlation?
# - Correlation shows how strongly two variables are related to each other.
#
# What does negative correlation mean?
# - Negative correlation means when one variable increases, the other decreases.
#
# Q3.Define Machine Learning. What are the main components in Machine Learning?
# - Machine Learning is a way for computers to learn from data.
# Main components are data, model, algorithm, loss function, and optimizer.
#
# Q4.How does loss value help in determining whether the model is good or not?
# - Loss value tells how wrong the model’s predictions are. Lower loss means a better model.
#
# Q5.What are continuous and categorical variables?
# - Continuous variables have numeric values (like height).
# Categorical variables represent categories (like gender).
#
# Q6.How do we handle categorical variables in Machine Learning? What are the common techniques?
# -We convert them into numbers using Label Encoding or One-Hot Encoding.
#
# Q7.What do you mean by training and testing a dataset?
# - Training data is used to teach the model, and testing data is used to check its performance.
#
# Q8.What is sklearn.preprocessing?
# - It is a module in sklearn used for scaling, encoding, and normalizing data.
#
# Q9.What is a Test set?
# - A test set is the part of data used to evaluate the trained model.
#
# Q10.How do we split data for model fitting (training and testing) in Python?
# - We use train_test_split() from sklearn to divide data into train and test sets.
# How do you approach a Machine Learning problem?
# - Understand the problem, analyze data, preprocess it, train a model, and evaluate results.
#
# Q11.Why do we have to perform EDA before fitting a model to the data?
# - EDA helps us understand patterns, outliers, and relationships in data before modeling.
#
# Q12.What is correlation?
# - We use .corr() method or libraries like pandas and seaborn.
#
# Q13.What does negative correlation mean?
# - Negative correlation means when one variable increases, the other variable decreases.
#
# Q14.How can you find correlation between variables in Python?
# - We can use the .corr() function in pandas to find correlation between variables.
#
# Q15.What is an Optimizer? What are different types of optimizers? Explain each with an example.
# - An optimizer updates model parameters to reduce error.
# Common optimizers are:
# - Gradient Descent – updates parameters step by step
# - Adam – faster and commonly used
# - RMSprop – works well for neural networks
#
# Q16.What is sklearn.linear_model ?
# - It is a module in sklearn that contains linear models like Linear Regression and Logistic Regression.
#
# Q17.What does model.fit() do? What arguments must be given?
# - model.fit() trains the model.
# It needs input data (X) and target output (y).
#
# Q18.What does model.predict() do? What arguments must be given?
# - model.predict() is used to make predictions.
# It takes new input data (X) as argument.
#
# Q19.What are continuous and categorical variables?
# -Continuous variables have numeric values like height or weight.
# Categorical variables represent categories like gender or city.
#
# Q20.What is feature scaling? How does it help in Machine Learning?
# - Feature scaling brings data to the same range.
# It helps models train faster and perform better.
#
# Q21.How do we perform scaling in Python?
# - We use StandardScaler or MinMaxScaler from sklearn.
#
# Q22.What is sklearn.preprocessing?
# - It is a sklearn module used for scaling, encoding, and data transformation.
#
# Q23.How do we split data for model fitting (training and testing) in Python?
# - We use train_test_split() from sklearn.model_selection.
#
# Q24.Explain data encoding?
# - Data encoding converts categorical data into numerical form so models can understand it.
